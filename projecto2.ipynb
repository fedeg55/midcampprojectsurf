# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Cargar el archivo CSV en un DataFrame
df = pd.read_csv('df_surf.csv')

# %%
df = pd.read_csv('df_surf.csv')

pd.read_csv ('df_surf.csv')
# Out:
#      Unnamed: 0 board_adequate  board_how_many  board_length  \
# 0             0   More or less             5.0        1.8034
# 1             1   More or less             1.0        1.9304
# 2             2  Very suitable             3.0        1.7272
# 3             3  Very suitable             1.0        1.8034
# 4             4       Suitable             5.0        1.7780
# ..          ...            ...             ...           ...
# 159         159   More or less             3.0        1.8796
# 160         160  Very suitable             3.0        1.7526
# 161         161       Suitable             1.0        1.8796
# 162         162   More or less             6.0        1.8034
# 163         163   More or less             1.0        1.8034
#
#      board_nose_rocker board_nose_shape  board_tail_rocker  \
# 0                4.750          Pointed             2.3125
# 1                  NaN          Pointed                NaN
# ...

# %%
# 1. Comprobar valores NaN
nan_check = df.isna().sum()

print("1. Comprobar valores NaN:")
print(nan_check)
# Out:
# 1. Comprobar valores NaN:
# Unnamed: 0                        0
# board_adequate                    0
# board_how_many                    6
# board_length                      8
# board_nose_rocker               147
# board_nose_shape                  0
# board_tail_rocker               149
# board_tail_shape                  0
# board_thickness                  58
# board_type                        0
# board_volume                     63
# board_width                      56
# manoeuvres_01_paddling            2
# manoeuvres_02_drop                2
# manoeuvres_03_straight_ahead     19
# manoeuvres_04_wall_riding         3
# manoeuvres_05_floater             2
# manoeuvres_06_cut_back            3
# manoeuvres_07_carve               2
# manoeuvres_08_off_the_lip         1
# manoeuvres_09_tube                2
# manoeuvres_10_air                 9
# performance_control               2
# performance_ease_paddling         1
# performance_flotation             1
# ...

# %%
print("1. Comprobar valores NaN:")
print(nan_check)
# Out:
# 1. Comprobar valores NaN:
# Unnamed: 0                        0
# board_adequate                    0
# board_how_many                    6
# board_length                      8
# board_nose_rocker               147
# board_nose_shape                  0
# board_tail_rocker               149
# board_tail_shape                  0
# board_thickness                  58
# board_type                        0
# board_volume                     63
# board_width                      56
# manoeuvres_01_paddling            2
# manoeuvres_02_drop                2
# manoeuvres_03_straight_ahead     19
# manoeuvres_04_wall_riding         3
# manoeuvres_05_floater             2
# manoeuvres_06_cut_back            3
# manoeuvres_07_carve               2
# manoeuvres_08_off_the_lip         1
# manoeuvres_09_tube                2
# manoeuvres_10_air                 9
# performance_control               2
# performance_ease_paddling         1
# performance_flotation             1
# ...

# %%
# 2. Renombrar las columnas
df.columns = df.columns.str.lower().str.replace(' ', '_')

# 3. Comprobar duplicados
df = df.drop_duplicates()

# %%
print("\n2. Columnas renombradas:")
print(df.columns)
# Out:
# 2. Columnas renombradas:
# Index(['unnamed:_0', 'board_adequate', 'board_how_many', 'board_length',
#        'board_nose_rocker', 'board_nose_shape', 'board_tail_rocker',
#        'board_tail_shape', 'board_thickness', 'board_type', 'board_volume',
#        'board_width', 'manoeuvres_01_paddling', 'manoeuvres_02_drop',
#        'manoeuvres_03_straight_ahead', 'manoeuvres_04_wall_riding',
#        'manoeuvres_05_floater', 'manoeuvres_06_cut_back',
#        'manoeuvres_07_carve', 'manoeuvres_08_off_the_lip',
#        'manoeuvres_09_tube', 'manoeuvres_10_air', 'performance_control',
#        'performance_ease_paddling', 'performance_flotation',
#        'performance_hold', 'performance_manoeuvrability',
#        'performance_passing_through', 'performance_stability',
#        'performance_surf_speed', 'surfer_age', 'surfer_exercise_frequency',
#        'surfer_experience', 'surfer_gender', 'surfer_height', 'surfer_style',
# ...

# %%
# 4. Dividir en categóricos y numéricos
categorical_columns = ['surfer_exercise_frequency', 'board_type', 'surfer_gender', 'wave_height']
numeric_columns = df.columns.difference(categorical_columns)

df_categorical = df[categorical_columns]
df_numeric = df[numeric_columns]

# %%
print("Categorical:")
print(df_categorical.head())
# Out:
# Categorical:
#   surfer_exercise_frequency  board_type surfer_gender wave_height
# 0               Once a week  Shortboard          Male           3
# 1              Twice a week  All-around        Female           2
# 2              Once a month  Shortboard          Male        2, 5
# 3              Twice a week  Shortboard          Male        3, 6
# 4              Twice a week  All-around          Male           5

# %%
print("Numeric:")
print(df_numeric.head())
# Out:
# Numeric:
#   board_adequate  board_how_many  board_length  board_nose_rocker  \
# 0   More or less             5.0        1.8034               4.75
# 1   More or less             1.0        1.9304                NaN
# 2  Very suitable             3.0        1.7272                NaN
# 3  Very suitable             1.0        1.8034                NaN
# 4       Suitable             5.0        1.7780                NaN
#
#   board_nose_shape  board_tail_rocker  \
# 0          Pointed             2.3125
# 1          Pointed                NaN
# 2          Pointed                NaN
# 3          Pointed                NaN
# 4          Pointed                NaN
#
#                                     board_tail_shape  board_thickness  \
# 0                    Outward (Round, Round-Pin, Pin)           2.3125
# 1                           Neutral (Squash, Square)              NaN
# 2                           Neutral (Squash, Square)           2.5625
# ...

# %%
# Configurar pandas para mostrar todas las columnas
pd.set_option('display.max_columns', None)

# Cargar los datos desde el archivo CSV
df = pd.read_csv('df_surf.csv')


# Imprimir el DataFrame con todas las columnas visibles
print(df)
# Out:
#      Unnamed: 0 board_adequate  board_how_many  board_length  \
# 0             0   More or less             5.0        1.8034
# 1             1   More or less             1.0        1.9304
# 2             2  Very suitable             3.0        1.7272
# 3             3  Very suitable             1.0        1.8034
# 4             4       Suitable             5.0        1.7780
# ..          ...            ...             ...           ...
# 159         159   More or less             3.0        1.8796
# 160         160  Very suitable             3.0        1.7526
# 161         161       Suitable             1.0        1.8796
# 162         162   More or less             6.0        1.8034
# 163         163   More or less             1.0        1.8034
#
#      board_nose_rocker board_nose_shape  board_tail_rocker  \
# 0                4.750          Pointed             2.3125
# 1                  NaN          Pointed                NaN
# ...

# %%
# 5. Análisis de datos categóricos
categorical_freq_table = df_categorical['board_type'].value_counts().plot(kind='bar')
categorical_bar_plot = df_categorical['surfer_gender'].value_counts().plot(kind='bar')



print("\n5. Tabla de frecuencias categóricas:")
print(categorical_freq_table)
print("\nGráfico de barras categórico:")
print(categorical_bar_plot)
# Out:
# 5. Tabla de frecuencias categóricas:
# Axes(0.125,0.11;0.775x0.77)
#
# Gráfico de barras categórico:
# Axes(0.125,0.11;0.775x0.77)

# %%
# verificando cantidad de participantes por genero

gender_distribution = df['surfer_gender'].value_counts()
print(gender_distribution)
# Out:
# Male      152
# Female     10
# Name: surfer_gender, dtype: int64

# %%
# 6. Análisis de datos numéricos
numeric_descriptive_stats = df_numeric.describe()
numeric_histogram = df_numeric['surfer_age'].plot(kind='hist')

# %%
import matplotlib.pyplot as plt
import pandas as pd

# creating a dataframe ,'board_type'
data = {'board_type': ['Shortboard', 'All-around', 'Funboard', 'Fish', 'Groveler', 'Semi-gun'],
        'count': [92, 47, 9, 8, 7, 1]}
df = pd.DataFrame(data)

# sorting the values
df = df.sort_values(by='count', ascending=False)

# creating the graph
plt.figure(figsize=(10, 6))
bars = plt.bar(df['board_type'], df['count'], color=['blue', 'green', 'orange', 'red', 'purple', 'gray'])

# Adding labels on the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, yval + 2, round(yval, 2), ha='center', color='black', fontsize=10)

plt.title('Frequency Chart - Types of Surfboards')
plt.xlabel('Board type')
plt.ylabel('Frequency')
plt.xticks(rotation=45)  # Rotar las etiquetas del eje x para una mejor legibilidad
plt.tight_layout()
plt.show()

# %%
# 7. Preferencias en determinadas tablas
preference_table = pd.crosstab(df_categorical['board_type'], df_categorical['surfer_exercise_frequency'])

# %%
print("Table of preferences by style and frequency:")
print(preference_table)
# Out:
# Table of preferences by style and frequency:
# surfer_exercise_frequency  Five times a week  More than once a day  \
# board_type
# All-around                                 6                     1
# Fish                                       2                     0
# Funboard                                   1                     0
# Groveler                                   0                     0
# Semi-gun                                   0                     0
# Shortboard                                23                     4
#
# surfer_exercise_frequency  Once a month  Once a week  Twice a week
# board_type
# All-around                            3            7            30
# Fish                                  0            3             3
# Funboard                              2            0             6
# Groveler                              1            0             6
# Semi-gun                              0            1             0
# ...

# %%
# 8. Análisis del rendimiento según las medidas físicas
correlation_matrix = df_numeric.corr()
height_weight_scatter = df_numeric.plot.scatter(x='surfer_height', y='surfer_weight')
# Out:
# C:\Users\fede_\AppData\Local\Temp\ipykernel_2564\1269607551.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df_numeric.corr()

# %%
print("\n8. Correlation matrix:")
print(correlation_matrix)
print("Height vs. weight scatter plot:")
print(height_weight_scatter)
# Out:
# 8. Correlation matrix:
#                              board_how_many  board_length  board_nose_rocker  \
# board_how_many                     1.000000     -0.056044           0.200731
# board_length                      -0.056044      1.000000          -0.309845
# board_nose_rocker                  0.200731     -0.309845           1.000000
# board_tail_rocker                  0.278267      0.325971          -0.073715
# board_thickness                   -0.043778      0.400528          -0.196133
# board_volume                      -0.037326      0.748488          -0.267375
# board_width                       -0.131853      0.480780          -0.156850
# performance_manoeuvrability        0.220586     -0.370203          -0.219233
# surfer_age                        -0.021128      0.071423           0.033108
# surfer_height                      0.193794      0.084701          -0.213182
# surfer_weight                      0.143407      0.133040          -0.228737
# ...

# %%
# Scatter and density plots
def plotScatterMatrix(df, plotSize, textSize):
    df = df.select_dtypes(include =[np.number]) # keep only numerical columns
    # Remove rows and columns that would lead to df being singular
    df = df.dropna('columns')
    df = df[[col for col in df if df[col].nunique() > 1]] # keep columns where there are more than 1 unique values
    columnNames = list(df)
    if len(columnNames) > 10: # reduce the number of columns for matrix inversion of kernel density plots
        columnNames = columnNames[:10]
    df = df[columnNames]
    ax = pd.plotting.scatter_matrix(df, alpha=0.75, figsize=[plotSize, plotSize], diagonal='kde')
    corrs = df.corr().values
    for i, j in zip(*plt.np.triu_indices_from(ax, k = 1)):
        ax[i, j].annotate('Corr. coef = %.3f' % corrs[i, j], (0.8, 0.2), xycoords='axes fraction', ha='center', va='center', size=textSize)
    plt.suptitle('Scatter and Density Plot')
    plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.scatter(data['surfer_style'], data['surfer_board'])
plt.xlabel('Surfer Style')
plt.ylabel('Surfer Board')
plt.title('Relation between Surfer Style and Surfer Board')
plt.xticks(rotation=45)  # To make the x-axis labels readable
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 2
#       1 plt.figure(figsize=(10, 10))
# ----> 2 plt.scatter(data['surfer_style'], data['surfer_board'])
#       3 plt.xlabel('Surfer Style')
#       4 plt.ylabel('Surfer Board')
#
# KeyError: 'surfer_style'

# %%
# Convert numeric columns to appropriate data types
numeric_columns = ['wave_height_max', 'board_length', 'performance']
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')

# Calculate mean performance by subject
mean_performance = df.groupby(df.index)['performance'].mean()

# Plot the mean performance
plt.figure(figsize=(10, 6))
mean_performance.plot(kind='bar', color='skyblue')
plt.title('Mean Performance by Subject')
plt.xlabel('Subject Identifier')
plt.ylabel('Mean Performance')
plt.xticks(rotation=45)
plt.tight_layout()

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[63], line 3
#       1 # Convert numeric columns to appropriate data types
#       2 numeric_columns = ['wave_height_max', 'board_length', 'performance']
# ----> 3 df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric, errors='coerce')
#       5 # Calculate mean performance by subject
#       6 mean_performance = df.groupby(df.index)['performance'].mean()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# ...
